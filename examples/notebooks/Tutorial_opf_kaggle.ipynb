# %% [markdown]
# # GridFM: a neural solver for AC Optimal Power Flow

# %% [markdown]
# ## Kaggle / local setup
#
# Run the next cell first. It sets `REPO`, `CONFIG`, `DATA`, and `LOG` for the rest of the notebook.
#
# On **Kaggle**: turn **Internet on** (Settings), pick a **GPU** (T4 is enough; skip TPU). The cell clones this branch, `pip install`s that clone, and writes data/logs under `/kaggle/working`.
#
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://www.kaggle.com/kernels/welcome?src=https://github.com/gridfm/gridfm-graphkit/blob/lfe-tutorial/examples/notebooks/Tutorial_opf_kaggle.ipynb)

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path

IN_KAGGLE = Path("/kaggle").is_dir()
GIT_BRANCH = "lfe-tutorial"
GIT_URL = "https://github.com/gridfm/gridfm-graphkit.git"


def _run(cmd):
    print("+", " ".join(map(str, cmd)))
    subprocess.check_call(cmd)


if IN_KAGGLE:
    REPO = Path("/kaggle/working/gridfm-graphkit")
    marker = REPO / "examples" / "notebooks" / "tutorial_opf_helpers.py"
    if not marker.is_file():
        _run(["git", "clone", "--depth", "1", "--branch", GIT_BRANCH, GIT_URL, str(REPO)])
    else:
        _run(["git", "-C", str(REPO), "fetch", "--depth", "1", "origin", GIT_BRANCH])
        _run(["git", "-C", str(REPO), "reset", "--hard", f"origin/{GIT_BRANCH}"])
    pip_cmd = [sys.executable, "-m", "pip", "install", "-q", str(REPO), "huggingface_hub"]
    try:
        import torch

        tag = torch.__version__
        pip_cmd += ["torch-scatter", "-f", f"https://data.pyg.org/whl/torch-{tag}.html"]
    except Exception:
        pass
    _run(pip_cmd)
    os.chdir(REPO)

    models = REPO / "examples" / "notebooks" / "models"
    links = [
        (
            "465594abc8eb4c96b908363afc84a0e1/artifacts/model/best_model_state_dict.pt",
            models / "case118_small_best_model_state_dict.pt",
        ),
        (
            "465594abc8eb4c96b908363afc84a0e1/artifacts/stats/normalizer_stats.pt",
            models / "case118_small_normalizer_stats.pt",
        ),
        (
            "f227514415974447befc64513a758432/artifacts/model/best_model_state_dict.pt",
            models / "case2000_small_best_model_state_dict.pt",
        ),
    ]
    root = Path("/kaggle/working/genco_results/opf_2seeds/experiments")
    missing = [str(p) for _, p in links if not p.is_file()]
    if missing:
        raise FileNotFoundError("Paper weights missing from clone: " + ", ".join(missing))
    for rel, src_pt in links:
        dest = root / rel
        dest.parent.mkdir(parents=True, exist_ok=True)
        if not dest.exists():
            dest.symlink_to(src_pt.resolve())

    fig_src = REPO / "examples" / "notebooks" / "figures"
    fig_dst = Path("/kaggle/working/figures")
    if fig_src.is_dir():
        shutil.copytree(fig_src, fig_dst, dirs_exist_ok=True)

    DATA = Path("/kaggle/working/data")
    LOG = Path("/kaggle/working/mlruns")
else:
    REPO = Path.cwd().resolve()
    while REPO != REPO.parent and not (
        REPO / "examples" / "config" / "HGNS_OPF_case118_tutorial.yaml"
    ).exists():
        REPO = REPO.parent
    DATA = REPO / "data"
    LOG = REPO / "mlruns"

CONFIG = REPO / "examples" / "config" / "HGNS_OPF_case118_tutorial.yaml"
assert CONFIG.is_file(), f"Config not found: {CONFIG}"
sys.path.insert(0, str(REPO / "examples" / "notebooks"))

import matplotlib.pyplot as plt
from mlflow.tracking import MlflowClient

from tutorial_opf_helpers import (
    compare_nb_test_genco_dc,
    compare_scratch_vs_finetune,
    latest_mlflow_run_id,
    plot_scratch_vs_finetune_val_curves,
    plot_test_gap_and_violations,
    plot_val_residual_boxplot,
    prepare_tutorial_opf_raw,
    solve_one_opf,
)

GENCO = REPO.parent / "genco_results" / "opf_2seeds" / "experiments"
client = MlflowClient(LOG.resolve().as_uri())
print("REPO", REPO)
print("DATA", DATA)
print("LOG", LOG)

# %% [markdown]
# ## What is AC Optimal Power Flow?
#
# Given a snapshot of the grid (loads, topology, generator costs and limits), AC-OPF finds the **cheapest generator dispatch** that still satisfies power balance and operating limits.
#
# The formulation below is a simplified version of the [PowerModels AC-OPF model](https://lanl-ansi.github.io/PowerModels.jl/stable/math-model/) (bus-injection form). Complex power is $S = P + jQ$.
#
# **Variables**
#
# - $S^g_k$ — complex power of generator $k$
# - $V_i$ — complex voltage at bus $i$
# - $S_{ij}$ — complex power flow on branch $(i,j)$ (both directions)
#
# **Objective** — minimize quadratic fuel cost of active generation
#
# $$
# \min \sum_{k \in G} c_{2k}\, P^g_k{}^2 + c_{1k}\, P^g_k + c_{0k}
# \qquad\text{with } P^g_k = \mathrm{Re}(S^g_k)
# $$
#
# **Constraints**
#
# 1. Reference-bus angle: $\angle V_r = 0$
# 2. Generator limits: $\underline{S}^g_k \le S^g_k \le \overline{S}^g_k$
# 3. Voltage limits: $\underline{v}_i \le |V_i| \le \overline{v}_i$
# 4. Power balance (KCL) at each bus: generation minus load minus shunt equals outgoing branch flows
# 5. Branch flow from Ohm's law on the $\pi$-model (admittance $Y_{ij}$, tap $T_{ij}$)
# 6. Thermal limits: $|S_{ij}| \le \overline{s}_{ij}$
# 7. Angle-difference limits: $\underline{\theta}_{ij} \le \angle(V_i V_j^*) \le \overline{\theta}_{ij}$
#
# Classical solvers (e.g. IPOPT via PowerModels) return a locally optimal $S^g, V, S_{ij}$. A neural OPF solver learns that mapping: **loads + costs + limits → dispatch and voltages**, much faster, with a small optimality gap if the constraints still hold.

# %% [markdown]
# Agenda:\
#     - loading the data
#     - Training a model
#     - Evaluating the model

# %% [markdown]
# # Load tutorial data
#
# Download `gridfm/opf_small_case118_ieee` from Hugging Face and **copy Hive partitions** into `data/nb_opf_case118/raw/` (`bus_data.parquet/scenario_partition=<n>/`, 200 scenarios each). Do not flatten into a single parquet file — `--compute_dc_ac_metrics` and streaming both expect this layout.

# %%
raw = prepare_tutorial_opf_raw(DATA, n_scenarios=1_000)
print("Hive raw at", raw)
print(
    "partitions",
    sorted(p.name for p in (raw / "bus_data.parquet").glob("scenario_partition=*"))[:5],
    "...",
)
# Out:
# Hive raw at /Users/apu/gridfm/gridfm-graphkit/data/nb_opf_case118/raw
# partitions ['scenario_partition=0', 'scenario_partition=1', 'scenario_partition=10', 'scenario_partition=11', 'scenario_partition=12'] ...

# %% [markdown]
# ## GENCO
#
# **GENCO** (GEometric Neural Corrective Optimizer) is a heterogeneous graph transformer that maps a grid snapshot to an AC-OPF solution. It runs $N$ correction steps: each step updates bus and generator embeddings, decodes a candidate $(P_g, V, \theta)$, completes the state with a physics decoder, then feeds power-balance residuals back into the next step.
#
# ![GENCO architecture](figures/genco_architecture.png)
#
# ### Inputs
#
# The grid is a heterogeneous graph: **bus** nodes, **generator** nodes, directed **branch** edges, and featureless bus–generator links. Unknown OPF variables are zeroed; loads, limits, costs, and topology stay visible.
#
# | Node / edge | What is fed in | YAML |
# | --- | --- | --- |
# | Bus | $P_d$, $Q_d$, $Q_g$, $V$, $\theta$, PQ/PV/REF flags, $V$ limits, $Q_g$ limits, shunts, $V_n$ | `model.input_bus_dim: 15` |
# | Generator | $P_g$, $P_g$ limits, quadratic cost $(c_0, c_1, c_2)$ | `model.input_gen_dim: 6` |
# | Branch | admittance, tap, angle limits, thermal rating | `model.edge_dim: 10` |
#
# Width and depth of the latent corrections are `model.hidden_size: 12`, `model.num_layers: 12` (one HT layer per correction step), and `model.attention_head: 8`.
#
# ### Outputs
#
# The last correction step is the OPF prediction $x_N$:
#
# - **Buses** — $V$ and $\theta$ (`model.output_bus_dim: 2`). $V$ is mapped into $[\underline{V}, \overline{V}]$ with a sigmoid (the **Sigmoid Bound** / OPF decoder in the figure).
# - **Generators** — $P_g$ (`model.output_gen_dim: 1`), likewise boxed into $[\underline{P}_g, \overline{P}_g]$.
# - **Completed state** — branch flows from Ohm's law; $Q_g$ recovered from reactive power balance (not a free decoder output).
#
# Ground truth $x^\ast$ is the IPOPT AC-OPF solution stored in the dataset.
#
# ### Loss
#
# `training.losses`, `training.loss_weights`, and `training.loss_args` are aligned lists. The objective is the weighted sum
#
# $$
# \mathcal{L}
# =
# 0.1\,\mathcal{L}_{\mathrm{phys}}
# +
# 0.1\,\mathcal{L}_{P_g}
# +
# 0.75\,\mathcal{L}_{V,\theta}
# +
# 0.001\,\mathcal{L}_{Q_g}.
# $$
#
# | Weight | YAML name | Role |
# | --- | --- | --- |
# | **0.75** | `MaskedBusMSE` | MSE of predicted vs IPOPT $V$ and $\theta$ (largest term). |
# | **0.1** | `MaskedGenMSE` | MSE of predicted vs IPOPT $P_g$. |
# | **0.1** | `LayeredWeightedPhysics` | Mean $\ell_2$ power-balance residual at every correction step. Inside this term, `loss_args.base_weight: 0.5` gives geometrically **larger weight to later steps** (same $\lambda^{N-i}$ idea as in the figure), then the weights are normalized to sum to 1. The `0.1` applies to that whole combination. |
# | **0.001** | `QgViolationPenalty` | Penalty when recovered $Q_g$ leaves $[\underline{Q}_g, \overline{Q}_g]$. |
#
# So the YAML is telling GENCO: match the IPOPT voltages most strongly, pull generator $P_g$ and physics residuals in more weakly, and keep a small $Q_g$ bound penalty.

# %% [markdown]
# # Training the model

# %% [markdown]
# Training uses the same CLI you would run in a terminal. We do **not** reimplement the datamodule, dataloaders, Lightning trainer, or loss loop in this notebook.
#
# ```bash
# gridfm_graphkit train --config <config.yaml> --data_path <data> --log_dir <logs>
# ```
#
# That command loads the YAML, builds `LitGridHeteroDataModule` (skipping graph conversion if `processed/` already exists), constructs the OPF task, and runs `trainer.fit`. Hyperparameters stay in the config; the next cells only print that YAML and invoke the same command.

# %% [markdown]
# The tutorial uses `examples/config/HGNS_OPF_case118_tutorial.yaml`. The next cell prints that file. What each field does:
#
# **`task`**
# - `task_name: OptimalPowerFlow` — predict voltages and generator dispatch (not a power-flow reconstruction task).
#
# **`data`**
# - `scenarios: [1000]` — use the first 1,000 scenarios of that network.
# - `test_ratio` / `val_ratio` — 10% test, 10% val, remaining ~80% train.
# - `mask_value: 0.0` — fill value for masked features.
#
# **`model`** (GENCO)
# - `hidden_size`, `num_layers`, `attention_head` — width and depth (12 layers, hidden 12, 8 heads).
#
# **`optimizer`**
# - AdamW at `learning_rate: 0.0005`, `betas: [0.9, 0.999]`.
# - `ReduceLROnPlateau` multiplies LR by `0.7` after `patience: 5` epochs of no improvement (`mode: min`).
#
# **`training`**
# - `batch_size: 64`, `epochs: 10`.
# - `accelerator` / `devices` / `strategy: auto` — Lightning device selection (GPU/MPS/CPU).
# - Losses (order matches `loss_weights` and `loss_args`):
#   - `LayeredWeightedPhysics` (0.1) — power-balance residuals; `base_weight: 0.5` scales deeper layers.
#   - `MaskedGenMSE` (0.1) — match \(P_g\) on generators.
#   - `MaskedBusMSE` (0.75) — match bus \(V, \theta\).
#   - `QgViolationPenalty` (0.001) — penalize reactive generation outside limits.

# %%
print(CONFIG.read_text())

# %%
# !gridfm_graphkit train \
  --config {CONFIG} \
  --data_path {DATA} \
  --log_dir {LOG} \
  --exp_name tutorial_opf \
  --log_every_n_steps 50 \
  --compute_dc_ac_metrics
# Out:
# Seed set to 0
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [device] hostname=Pfungen
# [device] Using Apple MPS (Metal Performance Shaders)
# Fitting normalizer on train set (3988 scenarios)
#
#   | Name    | Type              | Params | Mode
# ------------------------------------------------------
# 0 | model   | GNS_heterogeneous | 1.3 M  | train
# 1 | loss_fn | MixedLoss         | 0      | train
# ------------------------------------------------------
# 1.3 M     Trainable params
# 0         Non-trainable params
# 1.3 M     Total params
# 5.106     Total estimated model params size (MB)
# 355       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# creating train dataloader for rank  not distributed
# Epoch 0: 100%|██████████████████████| 63/63 [00:18<00:00,  3.44it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 15.71it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 14.14it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 14.28it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 12.93it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 13.26it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 13.53it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 13.36it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 10.99it/s]
# Epoch 1: 100%|██████████████████████| 63/63 [00:13<00:00,  4.83it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 15.10it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 15.22it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 15.07it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 14.70it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 14.94it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 15.07it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 14.95it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 15.01it/s]
# Epoch 2: 100%|██████████████████████| 63/63 [00:10<00:00,  6.14it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 10.20it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 11.94it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 13.03it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 13.80it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 13.92it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 14.11it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 14.36it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 14.51it/s]
# Epoch 3: 100%|██████████████████████| 63/63 [00:09<00:00,  6.56it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 17.90it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 16.16it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 16.70it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 16.70it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 16.45it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 16.12it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 15.96it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 15.76it/s]
# Epoch 4: 100%|██████████████████████| 63/63 [00:10<00:00,  6.15it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 17.22it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 17.01it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 16.50it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 16.24it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 16.21it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 16.03it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 15.84it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 15.88it/s]
# Epoch 5: 100%|██████████████████████| 63/63 [00:10<00:00,  6.21it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 15.85it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 16.16it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 16.02it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 16.14it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 15.70it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 15.71it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 15.39it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 15.08it/s]
# Epoch 6: 100%|██████████████████████| 63/63 [00:09<00:00,  6.34it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 18.31it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 16.42it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 16.19it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 16.32it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 16.51it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 16.63it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 16.84it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 16.91it/s]
# Epoch 7: 100%|██████████████████████| 63/63 [00:09<00:00,  6.85it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 17.55it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 16.96it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 16.31it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 15.67it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 15.81it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 15.97it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 15.98it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 16.03it/s]
# Epoch 8: 100%|██████████████████████| 63/63 [00:08<00:00,  7.30it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 17.27it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 17.47it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 17.37it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 17.31it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 17.21it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 17.32it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 17.07it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 16.63it/s]
# Epoch 9: 100%|██████████████████████| 63/63 [00:09<00:00,  6.80it/s, v_num=f447]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:  12%|██▌                 | 1/8 [00:00<00:00, 15.45it/s]
# Validation DataLoader 0:  25%|█████               | 2/8 [00:00<00:00, 15.67it/s]
# Validation DataLoader 0:  38%|███████▌            | 3/8 [00:00<00:00, 15.61it/s]
# Validation DataLoader 0:  50%|██████████          | 4/8 [00:00<00:00, 15.69it/s]
# Validation DataLoader 0:  62%|████████████▌       | 5/8 [00:00<00:00, 15.92it/s]
# Validation DataLoader 0:  75%|███████████████     | 6/8 [00:00<00:00, 15.72it/s]
# Validation DataLoader 0:  88%|█████████████████▌  | 7/8 [00:00<00:00, 15.78it/s]
# Validation DataLoader 0: 100%|████████████████████| 8/8 [00:00<00:00, 15.65it/s]
# Epoch 9: 100%|██████████████████████| 63/63 [00:09<00:00,  6.34it/s, v_num=f447]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████████████████| 63/63 [00:10<00:00,  6.18it/s, v_num=f447]
# Setup already done for stage=TrainerFn.TESTING, skipping...
# Testing DataLoader 0: 100%|███████████████████████| 8/8 [00:01<00:00,  4.85it/s]
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
#
# Computing ground-truth AC/DC metrics for nb_opf_case118...
#   Test split: 502 scenarios
#   Loaded 59236 bus rows, 26507 gen rows, 91465 branch rows, 502 runtime rows for 502 test scenarios
#   Computing AC power balance...
#   Computing DC power balance...
#   AC per-bus residuals saved to /Users/apu/gridfm/gridfm-graphkit/mlruns/450897086427353776/0a3688cb981e42839603b2345409f447/artifacts/test/nb_opf_case118_ac_bus_residuals.parquet
#   DC per-bus residuals saved to /Users/apu/gridfm/gridfm-graphkit/mlruns/450897086427353776/0a3688cb981e42839603b2345409f447/artifacts/test/nb_opf_case118_dc_bus_residuals.parquet
#   Aggregated OPF AC/DC metrics saved to /Users/apu/gridfm/gridfm-graphkit/mlruns/450897086427353776/0a3688cb981e42839603b2345409f447/artifacts/test/nb_opf_case118_opf_ac_dc_metrics.csv

# %%
rid = client.search_runs(
    [e.experiment_id for e in client.search_experiments()],
    order_by=["start_time DESC"],
    max_results=1,
)[0].info.run_id


def hist(name):
    try:
        h = sorted(client.get_metric_history(rid, name), key=lambda m: m.step)
    except Exception:
        return [], []
    return [m.step for m in h], [m.value for m in h]


fig, ax = plt.subplots(figsize=(8, 4))
for name, fmt in (
    ("Training Loss", "o-"),
    ("Training Loss_step", "o-"),
    ("Validation loss", "s-"),
):
    s, v = hist(name)
    if v:
        ax.plot(s, v, fmt, label=name)
ax.set_xlabel("step")
ax.set_ylabel("loss")
ax.legend()
plt.show()

# %% [markdown]
# After each correction step, GENCO decodes $(P_g, V, \theta)$, completes flows from Ohm's law, and checks **nodal power balance**. The mismatch is a complex residual per bus
#
# $$
# \Delta S_k = \Delta P_k + j\,\Delta Q_k,
# \qquad
# \Delta P_k = P_{g,k}-P_{d,k}+P_{\mathrm{shunt},k}-P_{\mathrm{inj},k},
# \quad
# \Delta Q_k = Q_{g,k}-Q_{d,k}+Q_{\mathrm{shunt},k}-Q_{\mathrm{inj},k}.
# $$
#
# The curve below is **`Validation layer_11_residual`**: mean over buses of $|\Delta S_k|=\sqrt{\Delta P_k^2+\Delta Q_k^2}$ on the **validation set**, at **layer 11** (last of `num_layers: 12`). That is the complex power-balance residual of the final OPF prediction $x_N$ (PBRes$^N$ in the architecture figure), in per-unit.
#
# A **downward** trend means the decoded voltages and dispatch are getting closer to satisfying KCL: less leftover $P$ and $Q$ at the buses. The physics term in the YAML (`LayeredWeightedPhysics`) is what pushes this down, on **held-out load scenarios** of the same grid (the validation split), not a different network.

# %%
s, v = hist("Validation layer_11_residual")
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(s, v, "o-")
ax.set_xlabel("step")
ax.set_ylabel(r"mean $|\Delta S|$ (p.u.)")
ax.set_title("Validation set: layer-11 complex power-balance residual")
plt.show()

# %% [markdown]
# GENCO is built as a **corrective** solver: each layer proposes a candidate OPF state, measures how far it is from power balance, and feeds that residual into the next layer. If that design works, $|\Delta S|$ on held-out scenarios should **shrink with depth** — later layers closer to KCL than early ones, with the last layer the tightest.
#
# The box plot is that check on the **validation set** after training: one box per layer, the spread of per-bus complex power-balance residuals. A downward shift across layers confirms the iterative physics feedback is actually refining the solution, not just fitting IPOPT voltages in a single shot.

# %%
plot_val_residual_boxplot(CONFIG, DATA, client, rid);
# Out:
# Fitting normalizer on train set (3988 scenarios)

# %% [markdown]
# Same val batches, **trained checkpoint overlaid on random init**. Stacking layers alone should not systematically drive $|\Delta S|$ down; if it did, the trained drop would not be evidence of learned corrections. Large random-init residuals at every depth, with no clear decline, is the control we want.

# %%
plot_val_residual_boxplot(CONFIG, DATA, client, rid, overlay=True);
# Out:
# Fitting normalizer on train set (3988 scenarios)

# %% [markdown]
# We now look at **test-set** results: the held-out 10% of this notebook run (same scenario split as training). The table compares the Tiny GENCO we just trained to DC-OPF on that split. Both columns are read from MLflow `artifacts/test/` (`*_metrics.csv` for GENCO, `*_opf_ac_dc_metrics.csv` for DC-OPF).

# %%
compare_nb_test_genco_dc(client, rid)
# Out:
# Test set (502 scenarios, run 0a3688cb…) from /Users/apu/gridfm/gridfm-graphkit/mlruns/450897086427353776/0a3688cb981e42839603b2345409f447/artifacts/test
#                       metric   GENCO  DC-OPF
# 0    Mean optimality gap (%)  8.9296  4.7882
# 1      Avg. active res. (MW)  6.1444  2.4800
# 2  Avg. reactive res. (MVar)  1.0772     NaN
# 3   Thermal viol. from (MVA)  0.0731  0.1081
# 4     Thermal viol. to (MVA)  0.0602  0.1077
# 5   Mean Qg violation (MVar)  5.9468     NaN

# %% [markdown]
# These test numbers are **too weak** — Tiny loses to DC-OPF here because we did not train long enough (and not on enough data). This notebook run is **10 epochs** on **1,000** scenarios with `hidden_size: 12` (~1.3M parameters).
#
# The IEEE 118 **Small** model in the paper was trained for **200 epochs** on the full Datakit **250,000** scenarios with `hidden_size: 24` (~5M parameters). The loss, optimizer, and LR schedule (`ReduceLROnPlateau`, factor 0.7, patience 5) are the same; what changed is the budget: more data, more epochs, and a wider model. The next cells load that paper checkpoint.

# %% [markdown]
# # Evaluate GENCO Small (paper checkpoint)
#
# The Tiny run above was trained in this notebook (`hidden_size: 12`). The paper's **Small** model uses `hidden_size: 24` (~5M parameters). The next cell loads seed-1 of `HGNS_OPF_datakit_case118_small` from `opf_2seeds` and runs `gridfm_graphkit evaluate` with that run's weights and `normalizer_stats.pt`. The YAML uses `networks: [case118_ieee]` so the stats key matches; `data/case118_ieee` is a symlink to the tutorial slice.

# %%
CONFIG_SMALL = REPO / "examples" / "config" / "HGNS_OPF_case118_small.yaml"
SMALL_RUN = GENCO / "465594abc8eb4c96b908363afc84a0e1"
MODEL_PATH = SMALL_RUN / "artifacts" / "model" / "best_model_state_dict.pt"
NORM_PATH = SMALL_RUN / "artifacts" / "stats" / "normalizer_stats.pt"
assert MODEL_PATH.is_file(), f"Missing checkpoint: {MODEL_PATH}"
assert NORM_PATH.is_file(), f"Missing normalizer: {NORM_PATH}"

# !gridfm_graphkit evaluate \
  --config {CONFIG_SMALL} \
  --data_path {DATA} \
  --log_dir {LOG} \
  --exp_name tutorial_opf_eval_small \
  --model_path {MODEL_PATH} \
  --normalizer_stats {NORM_PATH} \
  --compute_dc_ac_metrics
# Out:
# Seed set to 0
# Loading model weights from /Users/apu/gridfm/genco_results/opf_2seeds/experiments/465594abc8eb4c96b908363afc84a0e1/artifacts/model/best_model_state_dict.pt
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [device] hostname=Pfungen
# [device] Using Apple MPS (Metal Performance Shaders)
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Loaded normalizer stats from /Users/apu/gridfm/genco_results/opf_2seeds/experiments/465594abc8eb4c96b908363afc84a0e1/artifacts/stats/normalizer_stats.pt
# Restoring normalizer for case118_ieee from saved stats
# Testing: |                                                | 0/? [00:00<?, ?it/s]/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# Testing DataLoader 0: 100%|███████████████████████| 8/8 [00:02<00:00,  3.15it/s]
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
#
# Computing ground-truth AC/DC metrics for case118_ieee...
#   Test split: 502 scenarios
#   Loaded 59236 bus rows, 26507 gen rows, 91465 branch rows, 502 runtime rows for 502 test scenarios
#   Computing AC power balance...
#   Computing DC power balance...
#   AC per-bus residuals saved to /Users/apu/gridfm/gridfm-graphkit/mlruns/919058505556949684/183e1ecdc5764c138199b5960fc1502f/artifacts/test/case118_ieee_ac_bus_residuals.parquet
#   DC per-bus residuals saved to /Users/apu/gridfm/gridfm-graphkit/mlruns/919058505556949684/183e1ecdc5764c138199b5960fc1502f/artifacts/test/case118_ieee_dc_bus_residuals.parquet
#   Aggregated OPF AC/DC metrics saved to /Users/apu/gridfm/gridfm-graphkit/mlruns/919058505556949684/183e1ecdc5764c138199b5960fc1502f/artifacts/test/case118_ieee_opf_ac_dc_metrics.csv

# %%
eval_exp = [e for e in client.search_experiments() if e.name == "tutorial_opf_eval_small"]
eval_rid = client.search_runs(
    [eval_exp[0].experiment_id],
    order_by=["start_time DESC"],
    max_results=1,
)[0].info.run_id
compare_nb_test_genco_dc(client, eval_rid)
# Out:
# Test set (502 scenarios, run 183e1ecd…) from /Users/apu/gridfm/gridfm-graphkit/mlruns/919058505556949684/183e1ecdc5764c138199b5960fc1502f/artifacts/test
#                       metric   GENCO  DC-OPF
# 0    Mean optimality gap (%)  1.1851  4.7882
# 1      Avg. active res. (MW)  0.9664  2.4800
# 2  Avg. reactive res. (MVar)  0.2377     NaN
# 3   Thermal viol. from (MVA)  0.0399  0.1081
# 4     Thermal viol. to (MVA)  0.0415  0.1077
# 5   Mean Qg violation (MVar)  0.0005     NaN

# %% [markdown]
# ## Solve one OPF
#
# A trained GENCO checkpoint **is** the solver: one forward pass on a grid snapshot. No IPOPT, no iterative Newton loop at inference — just decode $(P_g, V, \theta)$ and complete $Q_g$ and flows from physics.
#
# The cell below loads the paper **Small** checkpoint (same weights as the evaluation above), takes the **first validation scenario** on IEEE 118, and prints generator dispatch and bus voltages next to the IPOPT AC-OPF labels and the DC-OPF solution stored in the dataset.

# %%
solve_one_opf(
    CONFIG_SMALL,
    DATA,
    model_path=MODEL_PATH,
    normalizer_stats=NORM_PATH,
)
# Out:
# Loaded normalizer stats from /Users/apu/gridfm/genco_results/opf_2seeds/experiments/465594abc8eb4c96b908363afc84a0e1/artifacts/stats/normalizer_stats.pt
# Restoring normalizer for case118_ieee from saved stats
# Validation scenario 7577  (one GENCO forward pass)
#     cost GENCO   cost IPOPT     cost DC  gap GENCO %  gap DC %  \
# 0  104044.2031  103952.5625  98789.1016       0.0882   -4.9671
#
#    mean |ΔS| GENCO (MVA)  mean |ΔP| GENCO (MW)  mean |ΔP| DC (MW)
# 0                 0.8694                 0.707             3.0424
# Generator dispatch (dispatchable only)
#     gen  Pg GENCO (MW)  Pg IPOPT (MW)  Pg DC (MW)  min     max
# 0     4     330.291992     358.979004     257.754  0.0   505.0
# 1     5      53.494999      16.916000       0.000  0.0    85.0
# 2    10       0.358000      -0.000000      -0.000  0.0   221.0
# 3    11     483.148987     485.000000     485.000  0.0   485.0
# 4    13      16.962000      17.000000      17.000  0.0    17.0
# 5    18      19.973000      20.000000      20.000  0.0    20.0
# 6    19      88.258003      98.258003      67.103  0.0   223.0
# 7    20      52.160999      53.000000      53.000  0.0    53.0
# 8    23     188.214996     195.000000     195.000  0.0   195.0
# 9    25       0.380000       0.000000       0.000  0.0   441.0
# 10   26     620.120972     617.458008     597.911  0.0   784.0
# 11   27     846.018982     844.393982     755.080  0.0  1182.0
# 12   34     508.368988     509.000000     509.000  0.0   509.0
# 13   35       2.759000      10.000000       0.000  0.0    10.0
# 14   36     392.278992     365.138000     503.590  0.0   637.0
# 15   40     433.834015     444.740997     432.026  0.0   653.0
# 16   41     107.439003     108.000000     108.000  0.0   108.0
# 17   46      78.250000      79.000000      79.000  0.0    79.0
# Average abs. Pg deviation: GENCO 20.30%, DC 19.65% (vs |Pg_IPOPT|, dispatchable gens with |Pg| > 1 MW)
# Bus voltages and injections
#      bus type  Vm GENCO  Vm IPOPT  |ΔP| GENCO (MW)  |ΔP| DC (MW)
# 0      0   PV     1.015     1.028            0.056         0.108
# 1      1   PQ     1.022     1.034            0.467         0.086
# 2      2   PQ     1.022     1.033            0.207         0.972
# 3      3   PV     1.054     1.060            0.255         0.396
# 4      4   PQ     1.050     1.058            0.336         3.013
# ..   ...  ...       ...       ...              ...           ...
# 113  113   PQ     1.011     1.020            1.107         0.066
# 114  114   PQ     1.009     1.019            0.592         0.007
# 115  115   PV     1.030     1.060            1.415         0.045
# 116  116   PQ     1.019     1.031            0.151         0.059
# 117  117   PQ     0.989     1.003            0.564         0.031
#
# [118 rows x 6 columns]

# %% [markdown]
# The tables above are **one** validation snapshot. The next cell runs the same Small checkpoint on the **full test split** and overlays GENCO vs DC-OPF distributions of optimality gap and constraint violations (mean over buses or branches in each scenario).

# %%
plot_test_gap_and_violations(CONFIG_SMALL, DATA, MODEL_PATH, NORM_PATH)
# Out:
# Loaded normalizer stats from /Users/apu/gridfm/genco_results/opf_2seeds/experiments/465594abc8eb4c96b908363afc84a0e1/artifacts/stats/normalizer_stats.pt
# Restoring normalizer for case118_ieee from saved stats
# Test samples: 502

# %% [markdown]
# IEEE 118 and the paper's 2,000-bus grid are **different networks**. The question here is transfer: if GENCO has already learned AC-OPF on a large synthetic grid, do those weights help on IEEE 118 when you only have **1,000** labeled snapshots?
#
# The case2000 **Small** checkpoint (`HGNS_OPF_datakit_case2000_small_seed1`, `hidden_size: 24`, 12 layers) matches this YAML, so `load_state_dict` works. Physics is the same; topology, limits, and load patterns are not. **Scratch** trains that width from random init for 20 epochs on this 1,000-scenario slice. **Fine-tune** starts from the case2000 weights and adapts them to 118. There is no Tiny (`hidden_size: 12`) case2000 run in `opf_2seeds`.

# %%
CONFIG_FEW_SMALL = REPO / "examples" / "config" / "HGNS_OPF_case118_fewshot_small.yaml"
PRETRAINED_2K_SMALL = (
    GENCO / "f227514415974447befc64513a758432" / "artifacts" / "model" / "best_model_state_dict.pt"
)
assert CONFIG_FEW_SMALL.is_file(), f"Missing config: {CONFIG_FEW_SMALL}"
assert PRETRAINED_2K_SMALL.is_file(), f"Missing case2000 Small checkpoint: {PRETRAINED_2K_SMALL}"

# !gridfm_graphkit train \
  --config {CONFIG_FEW_SMALL} \
  --data_path {DATA} \
  --log_dir {LOG} \
  --exp_name tutorial_opf_scratch_case2000_small20 \
  --log_every_n_steps 10 \
  --compute_dc_ac_metrics \
  --num_workers 16

# !gridfm_graphkit finetune \
  --config {CONFIG_FEW_SMALL} \
  --data_path {DATA} \
  --log_dir {LOG} \
  --exp_name tutorial_opf_ft_case2000_small \
  --model_path {PRETRAINED_2K_SMALL} \
  --log_every_n_steps 10 \
  --compute_dc_ac_metrics \
  --num_workers 16

compare_scratch_vs_finetune(
    client,
    latest_mlflow_run_id(client, "tutorial_opf_scratch_case2000_small20"),
    latest_mlflow_run_id(client, "tutorial_opf_ft_case2000_small"),
)
# Out:
# Seed set to 0
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [device] hostname=Pfungen
# [device] Using Apple MPS (Metal Performance Shaders)
# Fitting normalizer on train set (3988 scenarios)
#
#   | Name    | Type              | Params | Mode
# ------------------------------------------------------
# 0 | model   | GNS_heterogeneous | 5.0 M  | train
# 1 | loss_fn | MixedLoss         | 0      | train
# ------------------------------------------------------
# 5.0 M     Trainable params
# 0         Non-trainable params
# 5.0 M     Total params
# 20.188    Total estimated model params size (MB)
# 355       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# creating train dataloader for rank  not distributed
# Epoch 0:  35%|███████▋              | 22/63 [00:11<00:21,  1.88it/s, v_num=2373]^CProcess Process-32:
# Process Process-29:
# Process Process-31:
# Process Process-30:
# Process Process-26:
# Process Process-25:
# Process Process-28:
# Process Process-27:
# Process Process-24:
# Process Process-23:
# Process Process-22:
#
# Process Process-20:
# Process Process-21:
# Process Process-19:
# Process Process-18:
# Process Process-17:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/CellaTraceback (most recent call last):
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 49, in _call_and_handle_interrupt
# r/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 3Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#       File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# 17, in _bootstrap
#     util._exit_function()
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
# return trainer_fn(*args, **kwargs)  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homTraceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeo  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^
# ut):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#    File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#     File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#    File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 598, in _fit_impl
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@    self._run(model, ckpt_path=ckpt_path)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1011, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1055, in _run_stage
#     self.fit_loop.run()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py", line 216, in run
#     self.advance()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py", line 458, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 152, in run
#     self.advance(data_fetcher)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/traini3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#       File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
# KeyboardInterrupt
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 192, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 270, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 177, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/core/module.py", line 1366, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/core/optimizer.py", line 154, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py", line 239, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/plugins/precision/precision.py", line 123, in optimizer_step
#     return optimizer.step(closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/optim/optimizer.py", line 516, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/optim/optimizer.py", line 81, in _use_grad
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/optim/adam.py", line 226, in step
#     loss = closure()
#            ^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/plugins/precision/precision.py", line 109, in _wrap_closure
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 146, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 131, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 319, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 329, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py", line 391, in training_step
#     return self.lightning_module.training_step(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/tasks/reconstruction_tasks.py", line 63, in training_step
#     _, loss_dict = self.shared_step(batch)
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/tasks/reconstruction_tasks.py", line 51, in shared_step
#     loss_dict = self.loss_fn(
#                 ^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/training/loss.py", line 336, in forward
#     loss_output = loss_fn(
#                   ^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/training/loss.py", line 688, in forward
#     Qg_under = Qg_under[min_penalty_mask].mean()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__main__.py", line 506, in main
#     main_cli(args)
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/cli.py", line 347, in main_cli
#     trainer.fit(model=model, datamodule=litGrid)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 560, in fit
#     call._call_and_handle_interrupt(
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 62, in _call_and_handle_interrupt
#     trainer._teardown()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1034, in _teardown
#     self.strategy.teardown()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py", line 532, in teardown
#     _optimizers_to_device(self.optimizers, torch.device("cpu"))
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/fabric/utilities/optimizer.py", line 27, in _optimizers_to_device
#     _optimizer_to_device(opt, device)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/fabric/utilities/optimizer.py", line 41, in _optimizer_to_device
#     v[key] = move_data_to_device(val, device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/fabric/utilities/apply_func.py", line 110, in move_data_to_device
#     return apply_to_collection(batch, dtype=_TransferableDataType, function=batch_to)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning_utilities/core/apply_func.py", line 66, in apply_to_collection
#     return function(data, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/fabric/utilities/apply_func.py", line 104, in batch_to
#     data_output = data.to(device, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 71288) is killed by signal: Interrupt: 2.
# Seed set to 0
# Loading model weights from /Users/apu/gridfm/genco_results/opf_2seeds/experiments/f227514415974447befc64513a758432/artifacts/model/best_model_state_dict.pt
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [device] hostname=Pfungen
# [device] Using Apple MPS (Metal Performance Shaders)
# Fitting normalizer on train set (3988 scenarios)
#
#   | Name    | Type              | Params | Mode
# ------------------------------------------------------
# 0 | model   | GNS_heterogeneous | 5.0 M  | train
# 1 | loss_fn | MixedLoss         | 0      | train
# ------------------------------------------------------
# 5.0 M     Trainable params
# 0         Non-trainable params
# 5.0 M     Total params
# 20.188    Total estimated model params size (MB)
# 355       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:377: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# creating train dataloader for rank  not distributed
# Epoch 0:   0%|                                           | 0/63 [00:00<?, ?it/s]^C    Traceback (most recent call last):
# Traceback (most recent call last):
# exitcode = _main(fd, parent_sentinel)object address  : 0x10c2a0640
# object address  : 0x10cbd4460
# object address  : 0x10b4720e0
# object address  : 0x10f009a80
# object refcount : 3
# object refcount : 3
# object refcount : 3
# object refcount : 3
# object type     : 0x1019ae4d8
#
# object type     : 0x102e7a4d8
# object type     : 0x100eee4d8
# object type     : 0x10112a4d8
# object type name: KeyboardInterrupt
# object type name: KeyboardInterrupt
# object type name: KeyboardInterrupt
# object type name: KeyboardInterrupt
# object repr     : object repr     : object repr     : object repr     : KeyboardInterrupt()KeyboardInterrupt()KeyboardInterrupt()
#
# KeyboardInterrupt()
# lost sys.stderr
# lost sys.stderr
#
# lost sys.stderr
# lost sys.stderr
# object address  : 0x10ea7d120
# object refcount : 3
# object type     : 0x1016324d8
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# object address  : 0x112a927a0
# lost sys.stderr
# object refcount : 3
# object type     : 0x104d924d8
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 122, in spawn_main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
# exitcode = _main(fd, parent_sentinel)
#                              ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "/opt/homebrew/Cellar/pytTraceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 122, in spawn_main
# hon@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 131, in _main
#     prepare(preparation_data)
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 246, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 131, in _main
# object address  : 0x10d4050c0
# object address  : 0x10ba538e0
# object address  : 0x110ae4340
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 131, in _main
# object refcount : 3
# object refcount : 3
# object refcount : 3
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 297, in _fixup_main_from_path
# object type     : 0x102c624d8
# object type     : 0x1011564d8
# object type     : 0x10145e4d8
# object type name: KeyboardInterrupt
# object type name: KeyboardInterrupt
# object type name: KeyboardInterrupt
# object repr     : object repr     : KeyboardInterrupt()object address  : 0x10ece4520
#
# lost sys.stderr
# KeyboardInterrupt()
# lost sys.stderr
#     object address  : 0x10ef0cd00
# object refcount : 3
# object type     : 0x1053424d8
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# prepare(preparation_data)
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 246, in prepare
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# object refcount : 3
# object type     : 0x1053424d8
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
#     main_content = runpy.run_path(main_path,
#     exitcode = _main(fd, parent_sentinel)
#      prepare(preparation_data)
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 246, in prepare
#              _fixup_main_from_path(data['init_main_from_path'])
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 297, in _fixup_main_from_path
#             main_content = runpy.run_path(main_path,
#                                    ^^ ^  _fixup_main_from_path(data['init_main_from_path'])^
#  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 5, in <module>
#     from gridfm_graphkit.__main__ import main
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__init__.py", line 1, in <module>
#     import gridfm_graphkit.datasets
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/__init__.py", line 1, in <module>
#     from gridfm_graphkit.datasets.normalizers import (
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/normalizers.py", line 6, in <module>
#     import pandas as pd
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
# ^^^^^^^^^^^^^^^^    from pandas.core.api import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/api.py", line 47, in <module>
# ^^^^^^^^^^^^^^    ^from pandas.core.groupby import (^
# ^^^  File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
# ^^^  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 297, in _fixup_main_from_path
# ^^^^
#     main_content = runpy.run_path(main_path,
#                    ^^^^^^^^  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 131, in _main
# ^^^^^^    ^from pandas.core.groupby.generic import (^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/groupby/generic.py", line 69, in <module>
#     from pandas.core.groupby import (
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1080, in get_code
#   File "<frozen importlib._bootstrap_external>", line 512, in cache_from_source
#   File "<frozen importlib._bootstrap_external>", line 134, in _path_split
# KeyboardInterrupt
# ^^^^
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 5, in <module>
#     prepare(preparation_data)
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 246, in prepare
#
#   File "<frozen runpy>", line 287, in run_path
#   File "<frozen runpy>", line 98, in _run_module_code
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 5, in <module>
# Traceback (most recent call last):
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 49, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 598, in _fit_impl
#     from gridfm_graphkit.__main__ import main
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__init__.py", line 1, in <module>
#     self._run(model, ckpt_path=ckpt_path)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1011, in _run
#     import gridfm_graphkit.datasets
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/__init__.py", line 1, in <module>
#     results = self._run_stage()
#               ^^    from gridfm_graphkit.datasets.normalizers import (^
# ^^  File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/normalizers.py", line 6, in <module>
# ^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1055, in _run_stage
#     import pandas as pd
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/api.py", line 23, in <module>
#     from pandas.core.algorithms import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/algorithms.py", line 77, in <module>
#     self.fit_loop.run()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py", line 216, in run
#     from pandas.core.array_algos.take import take_nd
#       File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/array_algos/take.py", line 24, in <module>
# self.advance()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py", line 458, in advance
#     from pandas.core.construction import ensure_wrapped_if_datetimelike
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/construction.py", line 20, in <module>
#     self.epoch_loop.run(self._data_fetcher)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 152, in run
#     from numpy import ma
#   File "<frozen importlib._bootstrap>", line 1412, in _handle_fromlist
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/__init__.py", line 727, in __getattr__
#     self.advance(data_fetcher)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 310, in advance
#     batch, _, __ = next(data_fetcher)
#         import numpy.ma as ma
#      File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/ma/__init__.py", line 42, in <module>
#             ^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/fetchers.py", line 134, in __next__
#     from . import core, extras
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/ma/core.py", line 1260, in <module>
#     batch = super().__next__()
#             ^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/loops/fetchers.py", line 61, in __next__
#     abs = absolute = _MaskedUnaryOperation(umath.absolute)
#                      ^^^^^^    ^batch = next(self.iterator)^
# ^^^^^^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^
# ^^  File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/ma/core.py", line 973, in __init__
# ^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/utilities/combined_loader.py", line 341, in __next__
#     super().__init__(mufunc)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/numpy/ma/core.py", line 946, in __init__
#     _fixup_main_from_path(data['init_main_from_path'])
#     out = next(self._iterator)
#           ^^^^^^^^^    ^self.__doc__ = ufunc.__doc__^^
# ^^  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 297, in _fixup_main_from_path
#  ^         ^   ^  ^  ^ ^ ^
# ^^^^  File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/utilities/combined_loader.py", line 78, in __next__
# ^^^^^^^^
# KeyboardInterrupt
#     main_content = runpy.run_path(main_path,
# out[i] = next(self.iterators[i])
#                      ^^^^ ^ ^  ^  ^ ^ ^ ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^  File "<frozen runpy>", line 287, in run_path
# ^^  File "<frozen runpy>", line 98, in _run_module_code
# ^^^  File "<frozen runpy>", line 88, in _run_code
# ^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 5, in <module>
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 734, in __next__
#     from gridfm_graphkit.__main__ import main
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__init__.py", line 1, in <module>
#     import gridfm_graphkit.datasets
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/__init__.py", line 1, in <module>
#     from gridfm_graphkit.datasets.normalizers import (
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/normalizers.py", line 6, in <module>
#     data = self._next_data()
# import pandas as pd
#     File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#          ^^^^^^^^^^^^^^    from pandas.core.api import (
# ^^  File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/api.py", line 23, in <module>
# ^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 1492, in _next_data
#     from pandas.core.algorithms import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/algorithms.py", line 33, in <module>
#     from pandas.util._decorators import doc
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1091, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1190, in get_data
# KeyboardInterrupt
#     from gridfm_graphkit.__main__ import main
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__init__.py", line 1, in <module>
#     idx, data = self._get_data()
#         import gridfm_graphkit.datasets
#        File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/__init__.py", line 1, in <module>
#       ^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 1454, in _get_data
#     from gridfm_graphkit.datasets.normalizers import (
#     success, data = self._try_get_data()
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/normalizers.py", line 6, in <module>
#                     ^^^^^^^^^^^^^^^^^^    ^import pandas as pd^
#
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 1285, in _try_get_data
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 122, in spawn_main
#     from pandas.core.api import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/api.py", line 1, in <module>
#     exitcode = _main(fd, parent_sentinel)
#                 from pandas._libs import (
#       data = self._data_queue.get(timeout=timeout)  File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/_libs/__init__.py", line 18, in <module>
# ^^
# ^^^^^^ ^   ^ ^ ^^ ^ ^^ ^^ ^ ^^^^^^^^    ^^from pandas._libs.interval import Interval^^^
# ^^^^^^^
# ^^^^^^  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 131, in _main
# ^^^^  File "pandas/_libs/interval.pyx", line 1, in init pandas._libs.interval
# ^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/queues.py", line 113, in get
#   File "pandas/_libs/hashtable.pyx", line 1, in init pandas._libs.hashtable
#     prepare(preparation_data)
#       File "pandas/_libs/missing.pyx", line 1, in init pandas._libs.missing
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 246, in prepare
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/_libs/tslibs/__init__.py", line 40, in <module>
# if not self._poll(timeout):
#                _fixup_main_from_path(data['init_main_from_path'])^^^^
# ^^^^^^^  File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/spawn.py", line 297, in _fixup_main_from_path
# ^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/connection.py", line 257, in poll
#     from pandas._libs.tslibs.conversion import localize_pydatetime
#   File "pandas/_libs/tslibs/conversion.pyx", line 1, in init pandas._libs.tslibs.conversion
#   File "pandas/_libs/tslibs/offsets.pyx", line 3336, in init pandas._libs.tslibs.offsets
# KeyboardInterrupt
#     main_content = runpy.run_path(main_path,
#      return self._poll(timeout)
#                     ^^^^^^^^ ^^^^^^^^^ ^ ^
#     File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/connection.py", line 440, in _poll
#   ^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "<frozen runpy>", line 287, in run_path
# r = wait([self], timeout)
#   File "<frozen runpy>", line 98, in _run_module_code
#    File "<frozen runpy>", line 88, in _run_code
#      File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 5, in <module>
#     ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     from gridfm_graphkit.__main__ import main
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__init__.py", line 1, in <module>
#     import gridfm_graphkit.datasets
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/__init__.py", line 1, in <module>
#     from gridfm_graphkit.datasets.normalizers import (
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/datasets/normalizers.py", line 6, in <module>
#     import pandas as pd
#     ready = selector.select(timeout)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#             ^^^^^^^    from pandas.core.api import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/api.py", line 28, in <module>
# ^^^^^^^^^^^^^^^^^
# from pandas.core.arrays import Categorical
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/selectors.py", line 415, in select
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^    ^from pandas.core.arrays.arrow.array import ArrowExtensionArray^
# ^^^^^^  File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py", line 52, in <module>
# ^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/bin/gridfm_graphkit", line 8, in <module>
#     sys.exit(main())
#             from pandas.core import (
#      File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#  ^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/__main__.py", line 506, in main
#     from pandas.core.ops.array_ops import (
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py", line 18, in <module>
#     main_cli(args)
#   File "/Users/apu/gridfm/gridfm-graphkit/gridfm_graphkit/cli.py", line 347, in main_cli
#     trainer.fit(model=model, datamodule=litGrid)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 560, in fit
#     from pandas._libs import (
#   File "<frozen importlib._bootstrap>", line 645, in parent
# KeyboardInterrupt
#     call._call_and_handle_interrupt(
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py", line 62, in _call_and_handle_interrupt
#     trainer._teardown()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/trainer.py", line 1034, in _teardown
#     self.strategy.teardown()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py", line 536, in teardown
#     self.lightning_module.cpu()
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/lightning/fabric/utilities/device_dtype_mixin.py", line 82, in cpu
#     return super().cpu()
#            ^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1150, in cpu
#     return self._apply(lambda t: t.cpu())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 928, in _apply
#     module._apply(fn)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 928, in _apply
#     module._apply(fn)
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 928, in _apply
#     module._apply(fn)
#   [Previous line repeated 3 more times]
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 955, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1150, in <lambda>
#     return self._apply(lambda t: t.cpu())
#                                  ^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 71489) is killed by signal: Interrupt: 2.
# Exception ignored in atexit callback: <function _exit_function at 0x10bd8b880>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/util.py", line 360, in _exit_function
#     p.join()
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/popen_fork.py", line 43, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/popen_fork.py", line 27, in poll
#     pid, sts = os.waitpid(self.pid, flag)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/apu/gridfm/gridfm-graphkit/venv/lib/python3.12/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 71531) is killed by signal: Terminated: 15.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 39
#      36 from tutorial_opf_helpers import compare_scratch_vs_finetune, latest_mlflow_run_id
#      38 ft_client = MlflowClient(LOG.resolve().as_uri())
# ---> 39 compare_scratch_vs_finetune(
#      40     ft_client,
#      41     latest_mlflow_run_id(ft_client, "tutorial_opf_scratch_case2000_small20"),
#      42     latest_mlflow_run_id(ft_client, "tutorial_opf_ft_case2000_small"),
#      43 )
#
# File ~/gridfm/gridfm-graphkit/examples/notebooks/tutorial_opf_helpers.py:971, in compare_scratch_vs_finetune(mlflow_client, scratch_run_id, finetune_run_id)
#     968 import pandas as pd
#     969 from IPython.display import display
# --> 971 scratch, dc, n_test, _ = _genco_dc_series(mlflow_client, scratch_run_id)
#     972 ft, _, _, _ = _genco_dc_series(mlflow_client, finetune_run_id)
#     973 rows = [
#     974     {
#     975         "metric": "Mean optimality gap (%)",
#    (...)   1003     },
#    1004 ]
#
# File ~/gridfm/gridfm-graphkit/examples/notebooks/tutorial_opf_helpers.py:795, in _genco_dc_series(mlflow_client, run_id)
#     789 genco_csvs = [
#     790     p
#     791     for p in test_dir.glob("*_metrics.csv")
#     792     if not p.name.endswith("_opf_ac_dc_metrics.csv")
#     793 ]
#     794 if not genco_csvs:
# --> 795     raise FileNotFoundError(f"No GENCO test metrics CSV under {test_dir}")
#     796 genco_csv = genco_csvs[0]
#     797 network = genco_csv.name.removesuffix("_metrics.csv")
#
# FileNotFoundError: No GENCO test metrics CSV under /Users/apu/gridfm/gridfm-graphkit/mlruns/975769941702290626/e7e08cb8946944f38a6f27c6a2642373/artifacts/test

# %% [markdown]
# Validation curves for the two 20-epoch runs above: **scratch** vs **case2000 Small finetune**. Left is `Validation loss`; middle is last-layer power-balance residual (`Validation layer_11_residual`). The right panel is **test-set mean optimality gap** for both models and **DC-OPF** (same test split as the table above).

# %%
plot_scratch_vs_finetune_val_curves(
    client,
    latest_mlflow_run_id(client, "tutorial_opf_scratch_case2000_small20"),
    latest_mlflow_run_id(client, "tutorial_opf_ft_case2000_small"),
)
